# %%
import requests
import pandas as pd
from pandas.core.common import flatten
import numpy as np
import re
import random
from selenium import webdriver
from selenium.common.exceptions import ElementClickInterceptedException
# pressing certain keys
# from selenium.webdriver.common.keys import Keys
import time
import pickle
from datetime import datetime
# using beautiful soup to find our data a bit easier
# from bs4 import BeautifulSoup
# also trying gazpacho soup
from gazpacho import Soup
# convert html to markdown
from markdownify import markdownify as md
# for US states
import us

# %%
# login via cookie
BASE_URL = 'https://www.linkedin.com'
def login_with_cookie(cookie_path):
    # first load chromedriver
    OPTIONS = webdriver.ChromeOptions()
    # make the browser pretty thin so the page doesn't have multiple scroll bars
    # width,height
    OPTIONS.add_argument("window-size=600,800")
    OPTIONS.headless = True
    # remove all these when watching it the first time
    # if we need to be a realer browser (not a headless chrome)
    print('opening chrome')
    driver = webdriver.Chrome('chromedriver',options=OPTIONS)
    # login with cookie, how long is cookie timeout? unknown
    # think about logging in via username and pass
    COOKIE_NAME = 'linkedin_cookies_2021-02-14.pkl'
    # load the page without the cookie
    driver.get(BASE_URL)
    # load the cookie
    with open(cookie_path, "rb") as f:
        cookies = pickle.load(f)  
    # cookies = pickle.load(open('meetup_cookies.pkl','rb'))    
    print('loading cookies')
    for cookie in cookies:
        driver.add_cookie(cookie)
    # load the page again after the cookie is loaded, this is the same as logging in
    print('opening chrome with cookies to login')
    driver.get(BASE_URL)
    # minimise the messages area
    minimise_msgs(driver)
    return driver

# %%
# minimise the messaging bit if it's open
def minimise_msgs(driver):
    # if this is open
    msg_min = len(driver.find_elements_by_class_name('msg-overlay-list-bubble--is-minimized'))
    if msg_min == 0:
        try:
            print('minimising the messages overlay')
            msg_buttons = driver.find_elements_by_class_name('msg-overlay-bubble-header__control')
            msg_buttons[1].click()
        except:
            pass
    else:
        pass

# %%
# we scroll in chunks because things don't load if we scroll to the bottom immediately
def scroll_to_bottom2(driver,scroll_num):
    pause = 2 # one sec is def too fast, script starts to fail to find the next page button
    while(scroll_num>0):
        print('scrolling down 800 pixels')
        driver.execute_script("window.scrollBy(0,800);")
        time.sleep(pause)
        scroll_num -= 1

# %%
# safest to get the loc manually via the URL
# e.g. location=Sydney%2C%20New%20South%20Wales%2C%20Australia
# first run basically finds the pagination -- fix the pagination.. look at the last number and make that the last page
# next loop grabs all job links
def search_grab_links_v3(driver,kws,loc,top_pages='1'):
    kws = kws.replace(' ','%20').replace(',','%2C')
    URL = BASE_URL + '/jobs/search/?keywords='+kws+'&'+'location='+loc
    # get the search engine results page (SERP)
    driver.get(URL)
    # add a sleep time, so the page is fully loaded before we scroll
#     time.sleep(3)
    # find the minimise messaging button, there's only 2 with this class
    # the first is the write new message button
    # only need to do this once because we're in the same session
    minimise_msgs(driver)
    # scroll to the bottom to load all the jobs, linkedin takes about 5x scrolls of 800px
    scroll_to_bottom2(driver,scroll_num=5)
    # grab the page's html as a string
    html = driver.page_source
    soup = Soup(html)
    # find total pages we have
    # driver.find_elements_by_xpath('//button[contains(@aria-label,"Page")]')[-1].text
    pagi = soup.find('li', {'class': 'pagination'}, partial=True)[-1].find('span').text
    # find all the job links anchor tags
    job_links1 = soup.find('a', {'class':'job-card-list__title'})
    # find all href links in the a tags, and cut them to minimum size /jobs/view/123456789/
    try:
        job_links = [re.search('^(.+)\?',x.attrs['href']).group(1) for x in job_links1]
    except Exception as e:
        job_links = ['nolink']
        print(f'Exception is {e}')
    # put the job links in our all_job_links list
    all_job_links = []
    all_job_links.append(job_links)
    
    # there's a chance there could be say 20 pages, and we don't want to wait this long
    if(top_pages == '1'):
        return all_job_links
    # pages is always a str for both below scenarios
    elif(top_pages=='all'):
        pages = pagi
    else:
        pages = top_pages
    
    # loop covers grabbing job links
    for i in range(2,int(pages)+1):
        # click the next page button, will click 2, since we're on 1 first
        try:
            print(f'clicking page button {i}')
#             driver.find_element_by_css_selector(f"button[aria-label='Page {i}']").click()
            driver.find_element_by_xpath(f"//button/span[contains(text(), '{i}')]/ancestor::button").click()
        except Exception as e:
            # If pop-up overlay appears, click the X button to close
            time.sleep(2) # Sometimes the pop-up takes time to load
            print(f'error {e}, retrying clicking page button {i} with …')
            driver.find_element_by_xpath(f"//button/span[contains(text(), '…')]/ancestor::button").click()
#             driver.find_element_by_css_selector(f"button[aria-label='Page {i}']").click()
        # wait for site to load
        time.sleep(1)
        # scroll to bottom
        scroll_to_bottom2(driver,scroll_num=5)
        # grab the page source
        html = driver.page_source
        # make it a soup
        soup = Soup(html)
        # find total pages we have
#         pagi = soup.find('li', {'class': 'pagination'}, partial=True)[-1].find('span').text
        # find all the job links anchor tags
        job_links1 = soup.find('a', {'class':'job-card-list__title'})
        try:
            job_links = [re.search('^(.+)\?',x.attrs['href']).group(1) for x in job_links1]
        except Exception as e:
            job_links = ['nolink']
            print(f'Exception is {e}')
        # put the job links in our all_job_links list
        all_job_links.append(job_links)
    
    # all_job_links is a list of lists, this last bit flattens it into a single list
    return list(flatten(all_job_links))

# %%
# safest to get the loc manually via the URL
# e.g. location=Sydney%2C%20New%20South%20Wales%2C%20Australia
# first run basically finds the pagination -- fix the pagination.. look at the last number and make that the last page
# next loop grabs all job links
def search_grab_links_v2(driver,kws,loc,top_pages='1'):
    kws = kws.replace(' ','%20').replace(',','%2C')
    URL = BASE_URL + '/jobs/search/?keywords='+kws+'&'+'location='+loc
    # get the search engine results page (SERP)
    driver.get(URL)
    # add a sleep time, so the page is fully loaded before we scroll
#     time.sleep(3)
    # find the minimise messaging button, there's only 2 with this class
    # the first is the write new message button
    # only need to do this once because we're in the same session
    minimise_msgs(driver)
    # scroll to the bottom to load all the jobs, linkedin takes about 5x scrolls of 800px
    scroll_to_bottom2(driver,scroll_num=5)
    # grab the page's html as a string
    html = driver.page_source
    soup = Soup(html)
    # find total pages we have
    # driver.find_elements_by_xpath('//button[contains(@aria-label,"Page")]')[-1].text
    pagi = soup.find('li', {'class': 'pagination'}, partial=True)[-1].find('span').text
    # find all the job links anchor tags
    job_links1 = soup.find('a', {'class':'job-card-list__title'})
    # find all href links in the a tags, and cut them to minimum size /jobs/view/123456789/
    try:
        job_links = [re.search('^(.+)\?',x.attrs['href']).group(1) for x in job_links1]
    except Exception as e:
        job_links = ['nolink']
        print(f'Exception is {e}')
    # put the job links in our all_job_links list
    all_job_links = []
    all_job_links.append(job_links)
    
    # there's a chance there could be say 20 pages, and we don't want to wait this long
    if(top_pages == '1'):
        return all_job_links
    # pages is always a str for both below scenarios
    elif(top_pages=='all'):
        pages = pagi
    else:
        pages = top_pages
    
    # loop covers grabbing job links
    for i in range(2,int(pages)+1):
        # click the next page button, will click 2, since we're on 1 first
        try:
            print(f'clicking page button {i}')
            driver.find_element_by_css_selector(f"button[aria-label='Page {i}']").click()
        except Exception as e:
            # If pop-up overlay appears, click the X button to close
            time.sleep(2) # Sometimes the pop-up takes time to load
            print(f'error {e}, retrying clicking page button {i}')
            driver.find_element_by_css_selector(f"button[aria-label='Page {i}']").click()
        # wait for site to load
        time.sleep(1)
        # scroll to bottom
        scroll_to_bottom2(driver,scroll_num=5)
        # grab the page source
        html = driver.page_source
        # make it a soup
        soup = Soup(html)
        # find total pages we have
#         pagi = soup.find('li', {'class': 'pagination'}, partial=True)[-1].find('span').text
        # find all the job links anchor tags
        job_links1 = soup.find('a', {'class':'job-card-list__title'})
        try:
            job_links = [re.search('^(.+)\?',x.attrs['href']).group(1) for x in job_links1]
        except Exception as e:
            job_links = ['nolink']
            print(f'Exception is {e}')
            
        # put the job links in our all_job_links list
        all_job_links.append(job_links)
    
    # all_job_links is a list of lists, this last bit flattens it into a single list
    return list(flatten(all_job_links))

# %%
# use some dirty method of cleaning this html so we can run NLP on it later
def soup_to_md(soup):
    # remove the divs that surround, gazpacho doesn't seem to have a way to select all
    temp1 = re.search('\n(.+)\n',str(soup)).group(1)
    # make it markdown to remove other tags
    temp2 = md(temp1)
    # remove \n created by markdown
    temp3 = temp2.replace('\n','')
    # remove *'s created by markdown
    temp4 = temp3.replace('*','')
    # replace >1 space with just 1 space
    temp5 = re.sub(' +',' ',temp4)
    return temp5

# %%
# 5 sec x 100 = 500 sec ≈ 8.3min
# 5 sec x 150 = 750 sec ≈ 12.5min
# 5 sec x 200 = 1000 sec ≈ 16.6min
# make the script to follow each of these links and grab the nice text
def grab_job_descs_v2(links):
    total_links = len(links)
    out = []
    
    for i,link in enumerate(links):
        try:
            print(f'grabbing link {link}, {i+1} of {total_links}')
            out.append(grab_desc_v2(link))
            time.sleep(5)
        except:
            print(f'this link failed {link}')
            
    return out

# %%
# clean this job details bit
def grab_job_details(soup):
    job_extra_keys_raw = soup.find('li', {'class': 'job-criteria'}, partial=True, mode='all')
    job_extra_vals_raw = soup.find('span', {'class': 'job-criteria'}, partial=True, mode='all')
    
    # some logic based on number of list items found
    num_keys = len(job_extra_keys_raw)
    if num_keys == 0 :
        return {}
    if num_keys == 1 :
        key = job_extra_keys_raw[0].text.title()
        val = job_extra_vals_raw[0].text
        return {key:val}
    else :
        job_extra_keys = [key.text.title() for key in job_extra_keys_raw]
        job_extra_vals = [val.text for val in job_extra_vals_raw]
        return dict(zip(job_extra_keys,job_extra_vals))

# %%
# what we do here is odd, this request is without login
# this is to preserve some kind of purity in your logged in account
# one consequence of this is that some jobs might not be public
# 2nd is that css and html is actually different for logged in vs public
def grab_desc_v2(link):
    BASE_URL = 'https://www.linkedin.com'
    URL = BASE_URL + link 
    res = requests.get(url=URL)
    # using this gazpacho branded Soup
    soup = Soup(res.text)
    # they all live in these *topcard* classes
    # job_card contains the organisation and location
    # job_title lives above the card in the h1
    job_card = soup.find('span', {'class': 'topcard'}, partial=True)
    job_title = soup.find('h1', {'class': 'topcard'}, partial=True).text
    job_org = job_card[0].text
    job_loc = job_card[1].text
    # grab job description
    soup_desc = soup.find('div', {'class': 'show-more-less'}, partial=True)
    job_desc = soup_to_md(soup_desc)
    # grab job extra details
    # there is a variable amount of these, sometimes there might be none
    # so we offshore our cleaning
    job_extra_details = grab_job_details(soup)
    return {
        'Job Title':job_title,
        'Company':job_org,
        'Job Location':job_loc,
        'Job URL':URL,
        'Job Description':job_desc,
        'Job Details':job_extra_details
    }

# %%
# job list to df
def joblist_to_df(listt):
    # make the df
    df1 = pd.DataFrame(listt)
    # json normalize the extra details
    df2 = pd.json_normalize(df1['Job Details'])
    # append extra details
    df3 = pd.concat([df1,df2],axis='columns')
    # remove the old extra details column
    df = df3.drop(columns=['Job Details'])
    return df

# %%
# %%time
# making the first good data frame
# login to linkedin with cookie
driver = login_with_cookie(cookie_path='linkedin_cookies_2021-02-14.pkl')
# use selenium to copy all job links
# https://www.linkedin.com/jobs/search/?f_PP=104769905%2C100992797&geoId=101452733&keywords=machine%20learning%20engineer&location=Australia&sortBy=R
keywords = 'solution engineer'
location = 'Australia'
all_job_links = search_grab_links_v3(driver=driver,kws=keywords,loc=location,top_pages='all')
# use requests and gazpacho to get all the details of a job
jobs = grab_job_descs_v2(all_job_links)
# make the list into a dataframe
jobs_df = joblist_to_df(jobs)
# drop the duplicates -- linkedin displays the same job from different recruiters sometimes
jobs_df = jobs_df.drop_duplicates(subset=['Job Title', 'Company', 'Job Location', 'Job Description',
       'Seniority Level', 'Employment Type', 'Job Function', 'Industries'])
jobs_df = jobs_df.reset_index(drop=True)
jobs_df
# Out:
# opening chrome
# loading cookies
# opening chrome with cookies to login
# minimising the messages overlay
# minimising the messages overlay
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 2
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 3
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 4
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 5
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 6
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 7
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 8
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 9
# error Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button/span[contains(text(), '9')]/ancestor::button"}
#   (Session info: headless chrome=92.0.4515.107)
# , retrying clicking page button 9 with …
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 10
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 11
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 12
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 13
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 14
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 15
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 16
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 17
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 18
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 19
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 20
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 21
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 22
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 23
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 24
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 25
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 26
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 27
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 28
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 29
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 30
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 31
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 32
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 33
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 34
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 35
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# clicking page button 36
# error Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button/span[contains(text(), '36')]/ancestor::button"}
#   (Session info: headless chrome=92.0.4515.107)
# , retrying clicking page button 36 with …
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# scrolling down 800 pixels
# this link failed /jobs/view/2647953120/
# grabbing link /jobs/view/2637633870/, 234 of 899
# grabbing link /jobs/view/2657374650/, 235 of 899
# grabbing link /jobs/view/2660336253/, 236 of 899
# grabbing link /jobs/view/2616696523/, 237 of 899
# this link failed /jobs/view/2616696523/
# grabbing link /jobs/view/2629782641/, 238 of 899
# grabbing link /jobs/view/2661714914/, 239 of 899
# this link failed /jobs/view/2661714914/
# grabbing link /jobs/view/2628545316/, 240 of 899
# this link failed /jobs/view/2628545316/
# grabbing link /jobs/view/2637638239/, 241 of 899
# grabbing link /jobs/view/2628523596/, 242 of 899
# grabbing link /jobs/view/2600122929/, 243 of 899
# grabbing link /jobs/view/2664895230/, 244 of 899
# grabbing link /jobs/view/2577809203/, 245 of 899
# grabbing link /jobs/view/2604281637/, 246 of 899
# this link failed /jobs/view/2604281637/
# grabbing link /jobs/view/2642089624/, 247 of 899
# this link failed /jobs/view/2642089624/
# grabbing link /jobs/view/2600886884/, 248 of 899
# grabbing link /jobs/view/2637638241/, 249 of 899
# this link failed /jobs/view/2637638241/
# grabbing link /jobs/view/2631319223/, 250 of 899
# this link failed /jobs/view/2631319223/
# grabbing link /jobs/view/2519060100/, 251 of 899
# grabbing link /jobs/view/2656593744/, 252 of 899
# this link failed /jobs/view/2656593744/
# grabbing link /jobs/view/2642780624/, 253 of 899
# grabbing link /jobs/view/2642777834/, 254 of 899
# grabbing link /jobs/view/2666989185/, 255 of 899
# grabbing link /jobs/view/2623055792/, 256 of 899
# grabbing link /jobs/view/2660126101/, 257 of 899
# this link failed /jobs/view/2660126101/
# grabbing link /jobs/view/2654886971/, 258 of 899
# grabbing link /jobs/view/2659723856/, 259 of 899
# grabbing link /jobs/view/2661715765/, 260 of 899
# grabbing link /jobs/view/2658300191/, 261 of 899
# grabbing link /jobs/view/2641053593/, 262 of 899
# grabbing link /jobs/view/2645733665/, 263 of 899
# grabbing link /jobs/view/2607179068/, 264 of 899
# grabbing link /jobs/view/2661200789/, 265 of 899
# grabbing link /jobs/view/2657398228/, 266 of 899
# this link failed /jobs/view/2657398228/
# grabbing link /jobs/view/2659866261/, 267 of 899
# this link failed /jobs/view/2659866261/
# grabbing link /jobs/view/2600102998/, 268 of 899
# grabbing link /jobs/view/2649157820/, 269 of 899
# this link failed /jobs/view/2649157820/
# grabbing link /jobs/view/2661720237/, 270 of 899
# grabbing link /jobs/view/2660576128/, 271 of 899
# this link failed /jobs/view/2660576128/
# grabbing link /jobs/view/2651896147/, 272 of 899
# this link failed /jobs/view/2651896147/
# grabbing link /jobs/view/2615532289/, 273 of 899
# grabbing link /jobs/view/2630733761/, 274 of 899
# this link failed /jobs/view/2630733761/
# grabbing link /jobs/view/2650984181/, 275 of 899
# grabbing link /jobs/view/2617948061/, 276 of 899
# grabbing link /jobs/view/2650174068/, 277 of 899
# grabbing link /jobs/view/2660983683/, 278 of 899
# grabbing link /jobs/view/2656970687/, 279 of 899
# grabbing link /jobs/view/2661716619/, 280 of 899
# this link failed /jobs/view/2661716619/
# grabbing link /jobs/view/2658251126/, 416 of 899
# grabbing link /jobs/view/2590988334/, 417 of 899
# grabbing link /jobs/view/2656320646/, 418 of 899
# this link failed /jobs/view/2656320646/
# grabbing link /jobs/view/2633430577/, 419 of 899
# this link failed /jobs/view/2633430577/
# grabbing link /jobs/view/2645905416/, 420 of 899
# this link failed /jobs/view/2645905416/
# grabbing link /jobs/view/2630107750/, 421 of 899
# grabbing link /jobs/view/2660058777/, 422 of 899
# this link failed /jobs/view/2660058777/
# grabbing link /jobs/view/2638422344/, 423 of 899
# this link failed /jobs/view/2638422344/
# grabbing link /jobs/view/2650928906/, 424 of 899
# grabbing link /jobs/view/2652779631/, 425 of 899
# this link failed /jobs/view/2652779631/
# grabbing link /jobs/view/2666511927/, 426 of 899
# this link failed /jobs/view/2666511927/
# grabbing link /jobs/view/2641057241/, 427 of 899
# grabbing link /jobs/view/2614793364/, 428 of 899
# this link failed /jobs/view/2614793364/
# grabbing link /jobs/view/2621697236/, 429 of 899
# grabbing link /jobs/view/2625828644/, 430 of 899
# this link failed /jobs/view/2625828644/
# grabbing link /jobs/view/2655035490/, 431 of 899
# this link failed /jobs/view/2655035490/
# grabbing link /jobs/view/2656336161/, 432 of 899
# grabbing link /jobs/view/2664225285/, 433 of 899
# grabbing link /jobs/view/2646286650/, 434 of 899
# grabbing link /jobs/view/2621694436/, 435 of 899
# grabbing link /jobs/view/2580861163/, 436 of 899
# this link failed /jobs/view/2580861163/
# grabbing link /jobs/view/2657938869/, 437 of 899
# grabbing link /jobs/view/2665382803/, 438 of 899
# this link failed /jobs/view/2665382803/
# grabbing link /jobs/view/2604885852/, 439 of 899
# grabbing link /jobs/view/2601239259/, 440 of 899
# this link failed /jobs/view/2601239259/
# grabbing link /jobs/view/2628904886/, 441 of 899
# this link failed /jobs/view/2628904886/
# grabbing link /jobs/view/2630724591/, 442 of 899
# grabbing link /jobs/view/2658063833/, 443 of 899
# this link failed /jobs/view/2658063833/
# grabbing link /jobs/view/2641057243/, 444 of 899
# grabbing link /jobs/view/2640347410/, 445 of 899
# grabbing link /jobs/view/2647341732/, 446 of 899
# grabbing link /jobs/view/2649134983/, 447 of 899
# grabbing link /jobs/view/2626627243/, 448 of 899
# grabbing link /jobs/view/2658875091/, 449 of 899
# this link failed /jobs/view/2658875091/
# grabbing link /jobs/view/2650131901/, 450 of 899
# this link failed /jobs/view/2650131901/
# grabbing link /jobs/view/2438706198/, 451 of 899
# grabbing link /jobs/view/2658209342/, 452 of 899
# this link failed /jobs/view/2658209342/
# grabbing link /jobs/view/2653097093/, 453 of 899
# grabbing link /jobs/view/2640396980/, 454 of 899
# grabbing link /jobs/view/2632000248/, 455 of 899
# grabbing link /jobs/view/2650782753/, 456 of 899
# this link failed /jobs/view/2650782753/
# grabbing link /jobs/view/2659563428/, 457 of 899
# grabbing link /jobs/view/2645670165/, 458 of 899
# grabbing link /jobs/view/2618791806/, 459 of 899
# grabbing link /jobs/view/2647530722/, 460 of 899
# grabbing link /jobs/view/2655475913/, 461 of 899
# grabbing link /jobs/view/2661240787/, 462 of 899
# grabbing link /jobs/view/2642096285/, 463 of 899
# grabbing link /jobs/view/2664564812/, 464 of 899
# this link failed /jobs/view/2664564812/
# grabbing link /jobs/view/2663907667/, 465 of 899
# this link failed /jobs/view/2663907667/
# grabbing link /jobs/view/2618751551/, 466 of 899
# grabbing link /jobs/view/2658812332/, 467 of 899
# this link failed /jobs/view/2658812332/
# grabbing link /jobs/view/2647522401/, 468 of 899
# grabbing link /jobs/view/2658297127/, 469 of 899
# this link failed /jobs/view/2658297127/
# grabbing link /jobs/view/2660704268/, 470 of 899
# grabbing link /jobs/view/2653335852/, 471 of 899
# grabbing link /jobs/view/2667035574/, 472 of 899
# grabbing link /jobs/view/2660321590/, 473 of 899
# grabbing link /jobs/view/2604943170/, 474 of 899
# this link failed /jobs/view/2604943170/
# grabbing link /jobs/view/2583327379/, 475 of 899
# grabbing link /jobs/view/2662377329/, 476 of 899
# grabbing link /jobs/view/2658970269/, 477 of 899
# grabbing link /jobs/view/2654403853/, 478 of 899
# grabbing link /jobs/view/2659513896/, 479 of 899
# grabbing link /jobs/view/2616508604/, 480 of 899
# grabbing link /jobs/view/2488357390/, 481 of 899
# this link failed /jobs/view/2488357390/
# grabbing link /jobs/view/2624556362/, 482 of 899
# this link failed /jobs/view/2624556362/
# grabbing link /jobs/view/2628512060/, 483 of 899
# grabbing link /jobs/view/2639212685/, 484 of 899
# grabbing link /jobs/view/2628520507/, 485 of 899
# this link failed /jobs/view/2628520507/
# grabbing link /jobs/view/2633316708/, 486 of 899
# this link failed /jobs/view/2633316708/
# grabbing link /jobs/view/2616512248/, 487 of 899
# this link failed /jobs/view/2616512248/
# grabbing link /jobs/view/2634655427/, 488 of 899
# grabbing link /jobs/view/2652736902/, 489 of 899
# this link failed /jobs/view/2652736902/
# grabbing link /jobs/view/2659081630/, 490 of 899
# grabbing link /jobs/view/2635950493/, 491 of 899
# this link failed /jobs/view/2635950493/
# grabbing link /jobs/view/2658295591/, 492 of 899
# this link failed /jobs/view/2658295591/
# grabbing link /jobs/view/2649150398/, 493 of 899
# grabbing link /jobs/view/2633745284/, 494 of 899
# grabbing link /jobs/view/2658197254/, 495 of 899
# this link failed /jobs/view/2658197254/
# grabbing link /jobs/view/2650049895/, 496 of 899
# grabbing link /jobs/view/2627255926/, 497 of 899
# this link failed /jobs/view/2627255926/
# grabbing link /jobs/view/2625189850/, 498 of 899
# grabbing link /jobs/view/2599197959/, 499 of 899
# this link failed /jobs/view/2599197959/
# grabbing link /jobs/view/2637688233/, 500 of 899
# grabbing link /jobs/view/2665756138/, 501 of 899
# this link failed /jobs/view/2665756138/
# grabbing link /jobs/view/2633216061/, 502 of 899
# this link failed /jobs/view/2633216061/
# grabbing link /jobs/view/2652787353/, 503 of 899
# grabbing link /jobs/view/2637603025/, 504 of 899
# grabbing link /jobs/view/2571213707/, 505 of 899
# grabbing link /jobs/view/2643679732/, 506 of 899
# grabbing link /jobs/view/2656797031/, 560 of 899
# this link failed /jobs/view/2656797031/
# grabbing link /jobs/view/2636899587/, 561 of 899
# grabbing link /jobs/view/2580740910/, 562 of 899
# this link failed /jobs/view/2580740910/
# grabbing link /jobs/view/2666499741/, 563 of 899
# grabbing link /jobs/view/2660108770/, 564 of 899
# this link failed /jobs/view/2660108770/
# grabbing link /jobs/view/2631320821/, 565 of 899
# this link failed /jobs/view/2631320821/
# grabbing link /jobs/view/2637601314/, 566 of 899
# grabbing link /jobs/view/2636630025/, 567 of 899
# grabbing link /jobs/view/2660113313/, 568 of 899
# grabbing link /jobs/view/2652066815/, 569 of 899
# this link failed /jobs/view/2652066815/
# grabbing link /jobs/view/2535408585/, 570 of 899
# this link failed /jobs/view/2535408585/
# grabbing link /jobs/view/2637602089/, 571 of 899
# this link failed /jobs/view/2637602089/
# grabbing link /jobs/view/2567520265/, 572 of 899
# this link failed /jobs/view/2567520265/
# grabbing link /jobs/view/2660325271/, 573 of 899
# grabbing link /jobs/view/2660326130/, 574 of 899
# grabbing link /jobs/view/2506772795/, 575 of 899
# grabbing link /jobs/view/2522297078/, 576 of 899
# this link failed /jobs/view/2522297078/
# grabbing link /jobs/view/2657378274/, 577 of 899
# grabbing link /jobs/view/2633710855/, 578 of 899
# grabbing link /jobs/view/2656344166/, 579 of 899
# this link failed /jobs/view/2656344166/
# grabbing link /jobs/view/2642008754/, 580 of 899
# grabbing link /jobs/view/2640332710/, 581 of 899
# grabbing link /jobs/view/2638160949/, 582 of 899
# grabbing link /jobs/view/2580846425/, 583 of 899
# grabbing link /jobs/view/2579852025/, 584 of 899
# this link failed /jobs/view/2579852025/
# grabbing link /jobs/view/2630766131/, 585 of 899
# grabbing link /jobs/view/2659917325/, 586 of 899
# grabbing link /jobs/view/2649745724/, 587 of 899
# grabbing link /jobs/view/2661258924/, 588 of 899
# this link failed /jobs/view/2661258924/
# grabbing link /jobs/view/2617221177/, 589 of 899
# grabbing link /jobs/view/2654914146/, 590 of 899
# grabbing link /jobs/view/2647557704/, 591 of 899
# grabbing link /jobs/view/2603620389/, 592 of 899
# this link failed /jobs/view/2603620389/
# grabbing link /jobs/view/2625801879/, 593 of 899
# grabbing link /jobs/view/2646700688/, 594 of 899
# grabbing link /jobs/view/2616512148/, 595 of 899
# grabbing link /jobs/view/2622290816/, 596 of 899
# this link failed /jobs/view/2622290816/
# grabbing link /jobs/view/2627632915/, 597 of 899
# grabbing link /jobs/view/2640146628/, 598 of 899
# grabbing link /jobs/view/2648515852/, 599 of 899
# this link failed /jobs/view/2648515852/
# grabbing link /jobs/view/2660903646/, 600 of 899
# grabbing link /jobs/view/2633141780/, 601 of 899
# grabbing link /jobs/view/2657044734/, 602 of 899
# grabbing link /jobs/view/2633947802/, 603 of 899
# grabbing link /jobs/view/2556825926/, 604 of 899
# this link failed /jobs/view/2556825926/
# grabbing link /jobs/view/2616513000/, 605 of 899
# grabbing link /jobs/view/2657324558/, 606 of 899
# grabbing link /jobs/view/2657392025/, 658 of 899
# grabbing link /jobs/view/2654398035/, 659 of 899
# grabbing link /jobs/view/2625606920/, 660 of 899
# grabbing link /jobs/view/2660719650/, 661 of 899
# grabbing link /jobs/view/2656183338/, 662 of 899
# grabbing link /jobs/view/2636815319/, 663 of 899
# grabbing link /jobs/view/2639380260/, 664 of 899
# grabbing link /jobs/view/2598024329/, 665 of 899
# grabbing link /jobs/view/2656850001/, 666 of 899
# grabbing link /jobs/view/2658961458/, 667 of 899
# ...
# grabbing link /jobs/view/2653782045/, 729 of 899
# this link failed /jobs/view/2653782045/
# grabbing link /jobs/view/2637605250/, 730 of 899
# grabbing link /jobs/view/2642748740/, 731 of 899
# this link failed /jobs/view/2642748740/
# grabbing link /jobs/view/2666161120/, 732 of 899
# grabbing link /jobs/view/2629937647/, 733 of 899
# this link failed /jobs/view/2629937647/
# grabbing link /jobs/view/2658225322/, 734 of 899
# grabbing link /jobs/view/2630130084/, 735 of 899
# grabbing link /jobs/view/2659573393/, 736 of 899
# grabbing link /jobs/view/2659573396/, 737 of 899
# this link failed /jobs/view/2659573396/
# grabbing link /jobs/view/2643972653/, 738 of 899
# grabbing link /jobs/view/2454029283/, 739 of 899
# this link failed /jobs/view/2454029283/
# grabbing link /jobs/view/2642499588/, 740 of 899
# this link failed /jobs/view/2642499588/
# grabbing link /jobs/view/2650439098/, 741 of 899
# this link failed /jobs/view/2650439098/
# grabbing link /jobs/view/2626626459/, 742 of 899
# grabbing link /jobs/view/2629788151/, 743 of 899
# this link failed /jobs/view/2629788151/
# grabbing link /jobs/view/2642089714/, 744 of 899
# grabbing link /jobs/view/2659919063/, 745 of 899
# grabbing link /jobs/view/2658921635/, 746 of 899
# this link failed /jobs/view/2658921635/
# grabbing link /jobs/view/2654609382/, 747 of 899
# grabbing link /jobs/view/2653472639/, 748 of 899
# grabbing link /jobs/view/2655886968/, 749 of 899
# grabbing link /jobs/view/2469457203/, 750 of 899
# this link failed /jobs/view/2469457203/
# grabbing link /jobs/view/2654772083/, 751 of 899
# this link failed /jobs/view/2654772083/
# grabbing link /jobs/view/2652119898/, 752 of 899
# this link failed /jobs/view/2652119898/
# grabbing link /jobs/view/2657297063/, 753 of 899
# grabbing link /jobs/view/1718273657/, 754 of 899
# this link failed /jobs/view/1718273657/
# grabbing link /jobs/view/2666491189/, 755 of 899
# grabbing link /jobs/view/2659914662/, 756 of 899
# this link failed /jobs/view/2659914662/
# grabbing link /jobs/view/2650097234/, 757 of 899
# this link failed /jobs/view/2650097234/
# grabbing link /jobs/view/2651784734/, 758 of 899
# grabbing link /jobs/view/2639008266/, 759 of 899
# this link failed /jobs/view/2639008266/
# grabbing link /jobs/view/2657449531/, 760 of 899
# grabbing link /jobs/view/2540034567/, 761 of 899
# this link failed /jobs/view/2540034567/
# grabbing link /jobs/view/2642747829/, 762 of 899
# this link failed /jobs/view/2642747829/
# grabbing link /jobs/view/2649840594/, 763 of 899
# this link failed /jobs/view/2649840594/
# grabbing link /jobs/view/2649842551/, 764 of 899
# grabbing link /jobs/view/2339540364/, 765 of 899
# this link failed /jobs/view/2339540364/
# grabbing link /jobs/view/2640350369/, 766 of 899
# this link failed /jobs/view/2640350369/
# grabbing link /jobs/view/2654577358/, 767 of 899
# grabbing link /jobs/view/2640354392/, 768 of 899
# this link failed /jobs/view/2640354392/
# grabbing link /jobs/view/2645664727/, 769 of 899
# this link failed /jobs/view/2645664727/
# grabbing link /jobs/view/2656971427/, 770 of 899
# grabbing link /jobs/view/2661401959/, 771 of 899
# this link failed /jobs/view/2661401959/
# grabbing link /jobs/view/2639259832/, 772 of 899
# grabbing link /jobs/view/2660555403/, 773 of 899
# this link failed /jobs/view/2660555403/
# grabbing link /jobs/view/2650777026/, 774 of 899
# this link failed /jobs/view/2650777026/
# grabbing link /jobs/view/2631789091/, 775 of 899
# this link failed /jobs/view/2631789091/
# grabbing link /jobs/view/2634664986/, 776 of 899
# this link failed /jobs/view/2634664986/
# grabbing link /jobs/view/2656849974/, 777 of 899
# this link failed /jobs/view/2656849974/
# grabbing link /jobs/view/2654410022/, 778 of 899
# grabbing link /jobs/view/2645699994/, 779 of 899
# grabbing link /jobs/view/2639212269/, 780 of 899
# grabbing link /jobs/view/2633735563/, 781 of 899
# grabbing link /jobs/view/2641079584/, 782 of 899
# grabbing link /jobs/view/2654580213/, 783 of 899
# this link failed /jobs/view/2654580213/
# grabbing link /jobs/view/2634655726/, 784 of 899
# grabbing link /jobs/view/2656966918/, 785 of 899
# this link failed /jobs/view/2656966918/
# grabbing link /jobs/view/2667016940/, 786 of 899
# grabbing link /jobs/view/2595654754/, 787 of 899
# this link failed /jobs/view/2595654754/
# grabbing link /jobs/view/2626628381/, 788 of 899
# this link failed /jobs/view/2626628381/
# grabbing link /jobs/view/2647543503/, 789 of 899
# grabbing link /jobs/view/2666984773/, 790 of 899
# grabbing link /jobs/view/2655888042/, 791 of 899
# grabbing link /jobs/view/2642081560/, 792 of 899
# grabbing link /jobs/view/2636839362/, 793 of 899
# this link failed /jobs/view/2636839362/
# grabbing link /jobs/view/2644908943/, 794 of 899
# grabbing link /jobs/view/2648406582/, 795 of 899
# this link failed /jobs/view/2648406582/
# grabbing link /jobs/view/2625806509/, 796 of 899
# this link failed /jobs/view/2625806509/
# grabbing link /jobs/view/2625191426/, 797 of 899
# grabbing link /jobs/view/2649123792/, 798 of 899
# this link failed /jobs/view/2649123792/
# grabbing link /jobs/view/2519000044/, 799 of 899
# this link failed /jobs/view/2519000044/
# grabbing link /jobs/view/2460876721/, 800 of 899
# grabbing link /jobs/view/2649134638/, 801 of 899
# grabbing link /jobs/view/2658194175/, 802 of 899
# grabbing link /jobs/view/2636820685/, 803 of 899
# grabbing link /jobs/view/2654608390/, 804 of 899
# this link failed /jobs/view/2654608390/
# grabbing link /jobs/view/2654404932/, 805 of 899
# grabbing link /jobs/view/2630118293/, 806 of 899
# grabbing link /jobs/view/2640532604/, 807 of 899
# grabbing link /jobs/view/2636815826/, 808 of 899
# this link failed /jobs/view/2636815826/
# grabbing link /jobs/view/2642111473/, 809 of 899
# grabbing link /jobs/view/2460877781/, 810 of 899
# this link failed /jobs/view/2460877781/
# grabbing link /jobs/view/2640358043/, 811 of 899
# this link failed /jobs/view/2640358043/
# grabbing link /jobs/view/2641075976/, 812 of 899
# grabbing link /jobs/view/2638879176/, 813 of 899
# this link failed /jobs/view/2638879176/
# grabbing link /jobs/view/2650769851/, 814 of 899
# grabbing link /jobs/view/2659864947/, 815 of 899
# grabbing link /jobs/view/2636832939/, 816 of 899
# grabbing link /jobs/view/2635934604/, 817 of 899
# grabbing link /jobs/view/2658889751/, 818 of 899
# grabbing link /jobs/view/2661219770/, 819 of 899
# this link failed /jobs/view/2661219770/
# grabbing link /jobs/view/2631342998/, 820 of 899
# this link failed /jobs/view/2631342998/
# grabbing link /jobs/view/2667359847/, 821 of 899
# grabbing link /jobs/view/2660761855/, 822 of 899
# grabbing link /jobs/view/2643981353/, 823 of 899
# grabbing link /jobs/view/2654739750/, 824 of 899
# this link failed /jobs/view/2654739750/
# grabbing link /jobs/view/2659938965/, 825 of 899
# grabbing link /jobs/view/2655865562/, 826 of 899
# this link failed /jobs/view/2655865562/
# grabbing link /jobs/view/2660763534/, 827 of 899
# grabbing link /jobs/view/2659812879/, 828 of 899
# grabbing link /jobs/view/2424249013/, 829 of 899
# grabbing link /jobs/view/2649012680/, 830 of 899
# grabbing link /jobs/view/2643981357/, 831 of 899
# grabbing link /jobs/view/2424242876/, 832 of 899
# this link failed /jobs/view/2424242876/
# grabbing link /jobs/view/2654407263/, 833 of 899
# grabbing link /jobs/view/2663433661/, 834 of 899
# this link failed /jobs/view/2663433661/
# grabbing link /jobs/view/2660823895/, 835 of 899
# this link failed /jobs/view/2660823895/
# grabbing link /jobs/view/2619836967/, 836 of 899
# grabbing link /jobs/view/2394772634/, 837 of 899
# this link failed /jobs/view/2394772634/
# grabbing link /jobs/view/2512373251/, 838 of 899
# this link failed /jobs/view/2512373251/
# grabbing link /jobs/view/2639852752/, 839 of 899
# grabbing link /jobs/view/2641602661/, 840 of 899
# grabbing link /jobs/view/2632922648/, 841 of 899
# grabbing link /jobs/view/2644467922/, 842 of 899
# this link failed /jobs/view/2644467922/
# grabbing link /jobs/view/2658235406/, 843 of 899
# grabbing link /jobs/view/2656343211/, 844 of 899
# grabbing link /jobs/view/2646199420/, 845 of 899
# grabbing link /jobs/view/2657973884/, 846 of 899
# this link failed /jobs/view/2657973884/
# grabbing link /jobs/view/2652069106/, 847 of 899
# this link failed /jobs/view/2652069106/
# grabbing link /jobs/view/2656393734/, 848 of 899
# grabbing link /jobs/view/2543472849/, 849 of 899
# this link failed /jobs/view/2543472849/
# grabbing link /jobs/view/2642111475/, 850 of 899
# grabbing link /jobs/view/1448885620/, 851 of 899
# this link failed /jobs/view/1448885620/
# grabbing link /jobs/view/2665657835/, 852 of 899
# this link failed /jobs/view/2665657835/
# grabbing link /jobs/view/2625867157/, 853 of 899
# grabbing link /jobs/view/2665229171/, 854 of 899
# grabbing link /jobs/view/2642095907/, 855 of 899
# this link failed /jobs/view/2642095907/
# grabbing link /jobs/view/2619858164/, 856 of 899
# grabbing link /jobs/view/2667347339/, 857 of 899
# this link failed /jobs/view/2667347339/
# grabbing link /jobs/view/2660735127/, 858 of 899
# grabbing link /jobs/view/2641607021/, 859 of 899
# this link failed /jobs/view/2641607021/
# grabbing link /jobs/view/2654617182/, 860 of 899
# this link failed /jobs/view/2654617182/
# grabbing link /jobs/view/2477296766/, 861 of 899
# grabbing link /jobs/view/2619858262/, 862 of 899
# this link failed /jobs/view/2619858262/
# grabbing link /jobs/view/2654475085/, 863 of 899
# grabbing link /jobs/view/2511261264/, 864 of 899
# grabbing link /jobs/view/2654612941/, 865 of 899
# grabbing link /jobs/view/2639121890/, 866 of 899
# this link failed /jobs/view/2639121890/
# grabbing link /jobs/view/2642083359/, 867 of 899
# grabbing link /jobs/view/2588423755/, 868 of 899
# grabbing link /jobs/view/2659084299/, 869 of 899
# grabbing link /jobs/view/2659088142/, 870 of 899
# grabbing link /jobs/view/2588177238/, 871 of 899
# grabbing link /jobs/view/2643313906/, 872 of 899
# this link failed /jobs/view/2643313906/
# grabbing link /jobs/view/2659225232/, 873 of 899
# this link failed /jobs/view/2659225232/
# grabbing link /jobs/view/2650782889/, 874 of 899
# grabbing link /jobs/view/2618756017/, 875 of 899
# this link failed /jobs/view/2618756017/
# grabbing link /jobs/view/2666496914/, 876 of 899
# this link failed /jobs/view/2666496914/
# grabbing link /jobs/view/2486220651/, 877 of 899
# grabbing link /jobs/view/2643682389/, 878 of 899
# this link failed /jobs/view/2643682389/
# grabbing link /jobs/view/2658214426/, 879 of 899
# grabbing link /jobs/view/2582613069/, 880 of 899
# grabbing link /jobs/view/2650785207/, 881 of 899
# grabbing link /jobs/view/2657392025/, 882 of 899
# grabbing link /jobs/view/2654398035/, 883 of 899
# grabbing link /jobs/view/2625606920/, 884 of 899
# grabbing link /jobs/view/2660719650/, 885 of 899
# grabbing link /jobs/view/2656183338/, 886 of 899
# grabbing link /jobs/view/2636815319/, 887 of 899
# this link failed /jobs/view/2636815319/
# grabbing link /jobs/view/2639380260/, 888 of 899
# grabbing link /jobs/view/2598024329/, 889 of 899
# this link failed /jobs/view/2598024329/
# grabbing link /jobs/view/2656850001/, 890 of 899
# grabbing link /jobs/view/2658961458/, 891 of 899
# grabbing link /jobs/view/2656848269/, 892 of 899
# grabbing link /jobs/view/2646777680/, 893 of 899
# grabbing link /jobs/view/2658227025/, 894 of 899
# this link failed /jobs/view/2658227025/
# grabbing link /jobs/view/2654576391/, 895 of 899
# grabbing link /jobs/view/2552490103/, 896 of 899
# this link failed /jobs/view/2552490103/
# grabbing link /jobs/view/2659511685/, 897 of 899
# grabbing link /jobs/view/2638506391/, 898 of 899
# grabbing link /jobs/view/2657052027/, 899 of 899
# this link failed /jobs/view/2657052027/
# CPU times: user 1min 14s, sys: 2.78 s, total: 1min 17s
#
# [566 rows x 9 columns]

# %%
# the li[number] will do for now for a quick fix
# driver.find_element_by_xpath('/html/body/div[5]/div[3]/div[3]/div/div/section[1]/div/div/section/div/ul/li[9]/button').click()

# %%
# %%time
jobs = grab_job_descs_v2(all_job_links)
# make the list into a dataframe
jobs_df = joblist_to_df(jobs)
# drop the duplicates -- linkedin displays the same job from different recruiters sometimes
jobs_df = jobs_df.drop_duplicates(subset=['Job Title', 'Company', 'Job Location', 'Job Description',
       'Seniority Level', 'Employment Type', 'Job Function', 'Industries'])
jobs_df = jobs_df.reset_index(drop=True)
jobs_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'all_job_links' is not defined

# %% [markdown]
# # Now we have our dataframe

# %%
jobs_df
# Out:
#                                             Job Title             Company  \
# 0                              Data & Quality Manager             Metcash
# 1           Senior Manager Digital Insights Analytics   Commonwealth Bank
# 2                      Analytics and Insights Manager              Domain
# 3                          Data and Analytics Manager     Macquarie Group
# 4                        Analytics & Insights Manager                Nine
# ..                                                ...                 ...
# 479                       Marketing Analytics Manager                 Sbs
# 480      EPMO Portfolio Financial & Reporting Manager               Optus
# 481                  Analyst - Quantitative Modelling  Bank of Queensland
# 482                                    Data Scientist                 ANZ
# 483  Credit Cards Product Manager, Citi Consumer Bank                Citi
#
#                                    Job Location  \
# 0    Macquarie Park, New South Wales, Australia
# 1            Sydney, New South Wales, Australia
# 2            Sydney, New South Wales, Australia
# 3            Sydney, New South Wales, Australia
# 4      North Sydney, New South Wales, Australia
# ..                                          ...
# 479                  New South Wales, Australia
# 480          Sydney, New South Wales, Australia
# 481             Newstead, Queensland, Australia
# 482              Melbourne, Victoria, Australia
# 483          Sydney, New South Wales, Australia
#
#                                             Job URL  \
# 0    https://www.linkedin.com/jobs/view/2658781767/
# 1    https://www.linkedin.com/jobs/view/2651938665/
# 2    https://www.linkedin.com/jobs/view/2615561143/
# 3    https://www.linkedin.com/jobs/view/2645644230/
# 4    https://www.linkedin.com/jobs/view/2650968303/
# ..                                              ...
# 479  https://www.linkedin.com/jobs/view/2644918260/
# 480  https://www.linkedin.com/jobs/view/2608215470/
# 481  https://www.linkedin.com/jobs/view/2520437408/
# 482  https://www.linkedin.com/jobs/view/2645676830/
# 483  https://www.linkedin.com/jobs/view/2612612684/
#
#                                        Job Description   Seniority Level  \
# 0     Join an award winning team who have created o...  Mid-Senior level
# 1     Senior ManagerData and Decision Science(12 mo...  Mid-Senior level
# 2     Analytics and Insights Manager - Sydney - Per...  Mid-Senior level
# 3     Data and Analytics ManagerSydney Are you a Da...    Not Applicable
# 4     Department/Team OverviewThe Product team is r...  Mid-Senior level
# ..                                                 ...               ...
# 479   There’s a reason people work at SBS. SBS is o...  Mid-Senior level
# 480   Optus’ vision is to be Australia’s most loved...  Mid-Senior level
# 481   Join an ASX 100 finance leader! Exciting grow...    Not Applicable
# 482   Data Scientist - Customer Resolutions Locatio...    Not Applicable
# 483   Job Id: 21296654 Product Manager – Coles Cred...    Not Applicable
#
#     Employment Type                                   Job Function  \
# 0         Full-time                         Information Technology
# 1         Full-time  Research, Analyst, and Information Technology
# 2         Full-time                 Analyst, Finance, and Research
# 3         Full-time                                        Finance
# 4         Full-time                         Information Technology
# ..              ...                                            ...
# 479       Full-time  Research, Analyst, and Information Technology
# 480       Full-time                Accounting/Auditing and Finance
# 481       Full-time                 Business Development and Sales
# 482       Full-time         Engineering and Information Technology
# 483       Full-time               Product Management and Marketing
#
#                                             Industries
# 0         Food & Beverages, Consumer Goods, and Retail
# 1    Information Technology and Services, Banking, ...
# 2    Information Technology and Services, Online Me...
# 3    Banking, Financial Services, and Investment Ba...
# 4                                         Online Media
# ..                                                 ...
# 479  Marketing and Advertising, Online Media, and B...
# 480  Telecommunications, Internet, and Information ...
# 481                                            Banking
# 482        Accounting, Banking, and Financial Services
# 483  Banking, Financial Services, and Investment Ba...
#
# [484 rows x 9 columns]

# %% [markdown]
# # Creating the final tables begins
#
# ## Feature Engineering for our Raw Data - Adding Salary and fixing some locations

# %%
filter_dollars = jobs_df['Job Description'].str.contains('\$')
# the below styles should be tailored for your country
# salary style1 $100,000 or $123456
reg_salary1 = '\$\d{2,3},{0,1}\d{3}'
filter_salary1 = jobs_df['Job Description'].str.contains(reg_salary1)
# salaray style2 = $100k or $123 k
reg_salary2 = '\$\d{2,3} {0,1}k'
filter_salary2 = jobs_df['Job Description'].str.contains(reg_salary2)
# jobs_df[filter_dollars]['Job Description'].str.extract('(\$\d{2,3},{0,1}\d{3})')
# jobs_df['Job Description'].str.extract('(\$\d{2,3} {0,1}k)')
# jobs_df[filter_dollars]['Job Description'].iloc[6]

# %%
# based on the patterns that salaries are posted in
# should be tailored for your country
# salary style1 $100,000 or $123456
# salaray style2 = $100k or $123 k
def grab_salary(jobs_df,salary_patterns):
    # the broadest filter, if they have a $ sign, should change this symbol for your own country
    # alternatively the broadest filter can be the word "salary" or "wage", etc
    filter_dollars = jobs_df['Job Description'].str.contains('\$')
    temp_output = []
    for pattern in salary_patterns:
        # setup the filter first
        filter_salary = jobs_df['Job Description'].str.contains(pattern)
        # create the df and extract all from that pattern
        temp_df = jobs_df[filter_salary]['Job Description'].str.extractall(f'({pattern})')
        # unstack puts all results in a new col rather but is still multiindex
        temp_df = temp_df.unstack()
        # this makes all salaries into style1
        temp_df = temp_df.apply(lambda x: x.str.replace('k',',000'))
        # remove the redundant multiindex
        temp_df.columns = temp_df.columns.droplevel()
        # add it to our list
        temp_output.append(temp_df)
    
    # return the concat of our lists
    return pd.concat(temp_output,axis='columns')

# %%
# do some cleaning on our salaries
# mainly because companies sometimes put a single salary 
# and sometimes put a salary range
# we want to compare average salaries between companies
def fix_salary(salary_df):
    # remove duplicates if a company somehow put both salary forms
    salary_df = salary_df.reset_index().drop_duplicates(subset='index').set_index('index')
    # remove the names of the columns and index
    salary_df.index.name=None
    salary_df.columns.name=None
    # make a dataframe of numbers so we can do math on it
    salary_df_num = salary_df.apply(lambda x: pd.to_numeric(x.str.replace('\$|,',''),errors='ignore',downcast='integer'))
    # min, max and avg salary in numbers
    salary_df['Min_Salary_Num'] = salary_df_num.min(axis='columns')
    salary_df['Max_Salary_Num'] = salary_df_num.max(axis='columns')
    salary_df['Avg_Salary_Num'] = salary_df[['Min_Salary_Num','Max_Salary_Num']].mean(axis='columns')
    # the 3 cols in nice number format
    salary_df['Min_Salary'] = salary_df['Min_Salary_Num'].apply(lambda x: '${:,.0f}'.format(x))
    salary_df['Max_Salary'] = salary_df['Max_Salary_Num'].apply(lambda x: '${:,.0f}'.format(x))
    salary_df['Avg_Salary'] = salary_df['Avg_Salary_Num'].apply(lambda x: '${:,.0f}'.format(x))
    # remove our intermediary columns
    return salary_df[['Min_Salary','Max_Salary','Avg_Salary','Min_Salary_Num','Max_Salary_Num','Avg_Salary_Num']]

# %%
salary_df = fix_salary(grab_salary(jobs_df,
                                   salary_patterns= [
                                       '\$\d{2,3},{0,1}\d{3}',
                                       '\$\d{2,3} {0,1}k'
                                   ]))
salary_df
# Out:
#     Min_Salary Max_Salary Avg_Salary  Min_Salary_Num  Max_Salary_Num  \
# 53    $119,442   $119,442   $119,442        119442.0        119442.0
# 180   $250,000   $250,000   $250,000        250000.0        250000.0
# 233   $100,000   $100,000   $100,000        100000.0        100000.0
# 242   $100,000   $140,000   $120,000        100000.0        140000.0
# 260   $111,077   $111,077   $111,077        111077.0        111077.0
# 292   $130,000   $130,000   $130,000        130000.0        130000.0
# 394   $175,000   $175,000   $175,000        175000.0        175000.0
# 456   $111,077   $111,077   $111,077        111077.0        111077.0
# 475    $60,000    $80,000    $70,000         60000.0         80000.0
# 500   $120,000   $120,000   $120,000        120000.0        120000.0
# 510   $120,000   $140,000   $130,000        120000.0        140000.0
#
#      Avg_Salary_Num
# 53         119442.0
# 180        250000.0
# 233        100000.0
# 242        120000.0
# 260        111077.0
# 292        130000.0
# 394        175000.0
# 456        111077.0
# 475         70000.0
# 500        120000.0
# 510        130000.0

# %%
# filter_state = jobs_df['Job Location'].str.contains('united',case=False)
# jobs_df['Job Location'][filter_state]

# %%
jobs_df1 = pd.concat([jobs_df,salary_df],axis='columns')
# make a copy of this for our raw data
jobs_df_withsal = jobs_df1.copy()
# split the state and city for tableau
# jobs_df_withsal['City'] = jobs_df_withsal['Job Location'].str.extract('^(.+),')
# jobs_df_withsal['State'] = jobs_df_withsal['Job Location'].str.extract(',(.+)$')
# remove all the NaNs
jobs_df_withsal.fillna('',inplace=True)
# make the state clean when the job puts the location in format State,Country
# filter_state = jobs_df_withsal['State'].str.contains('united',case=False)
# jobs_df_withsal['State'].loc[filter_state] = jobs_df_withsal['City'].loc[filter_state].apply(lambda x: us.states.lookup(x).abbr)
today = datetime.today().strftime('%Y-%M-%d')
jobs_df_withsal.to_csv(f'{keywords}_{location}_{today}.csv')
jobs_df_withsal
# Out:
#                                              Job Title  \
# 0                 Associate Solution Engineer - Sydney
# 1                           Presales solution Engineer
# 2                      Service Cloud Solution Engineer
# 3                          Associate Solution Engineer
# 4                                    Solution Engineer
# ..                                                 ...
# 561                                      RAMS Engineer
# 562  Field Services Engineer - Mechanical (Turbomac...
# 563                                Mechanical Engineer
# 564                Dynamics 365 F&O Solution Architect
# 565                         Technical Support Engineer
#
#                         Company                        Job Location  \
# 0            Appian Corporation  Sydney, New South Wales, Australia
# 1               Powell Software  Sydney, New South Wales, Australia
# 2                    Salesforce      Melbourne, Victoria, Australia
# 3                    Salesforce  Sydney, New South Wales, Australia
# 4                    Salesforce  Sydney, New South Wales, Australia
# ..                          ...                                 ...
# 561           Jobs on jobactive      Docklands, Victoria, Australia
# 562                Baker Hughes  Moomba, South Australia, Australia
# 563  Wave International Pty Ltd     Brisbane, Queensland, Australia
# 564                   Microsoft      Melbourne, Victoria, Australia
# 565        Agilent Technologies      Melbourne, Victoria, Australia
#
#                                             Job URL  \
# 0    https://www.linkedin.com/jobs/view/2622582377/
# 1    https://www.linkedin.com/jobs/view/2649187443/
# 2    https://www.linkedin.com/jobs/view/2652778606/
# 3    https://www.linkedin.com/jobs/view/2661212338/
# 4    https://www.linkedin.com/jobs/view/2661268390/
# ..                                              ...
# 561  https://www.linkedin.com/jobs/view/2659088142/
# 562  https://www.linkedin.com/jobs/view/2588177238/
# 563  https://www.linkedin.com/jobs/view/2650782889/
# 564  https://www.linkedin.com/jobs/view/2486220651/
# 565  https://www.linkedin.com/jobs/view/2658214426/
#
#                                        Job Description Seniority Level  \
# 0     At Appian, we’re seeking to grow our culture ...       Associate
# 1                                                            Associate
# 2     To get the best candidate experience, please ...  Not Applicable
# 3     To get the best candidate experience, please ...  Not Applicable
# 4     To get the best candidate experience, please ...  Not Applicable
# ..                                                 ...             ...
# 561   We currently have a career defining opportuni...     Entry level
# 562   This is not an active position, this posting ...     Entry level
# 563   Leading Engineering Consultancy working from ...     Entry level
# 564   The Microsoft Asia Business Application Domai...  Not Applicable
# 565   Agilent inspires and supports discoveries tha...     Entry level
#
#     Employment Type                            Job Function  \
# 0         Full-time  Engineering and Information Technology
# 1         Full-time        Sales and Information Technology
# 2         Full-time  Engineering and Information Technology
# 3         Full-time  Engineering and Information Technology
# 4         Full-time  Engineering and Information Technology
# ..              ...                                     ...
# 561       Full-time  Engineering and Information Technology
# 562       Full-time                  Information Technology
# 563       Full-time  Engineering and Information Technology
# 564       Full-time  Engineering and Information Technology
# 565       Full-time                  Information Technology
#
#                                             Industries Min_Salary Max_Salary  \
# 0                                    Computer Software
# 1                  Information Technology and Services
# 2    Computer Software, Information Technology and ...
# 3    Computer Software, Information Technology and ...
# 4    Computer Software, Information Technology and ...
# ..                                                 ...        ...        ...
# 561          Restaurants, Food & Beverages, and Design
# 562  Information Technology and Services, Computer ...
# 563  Staffing and Recruiting, Oil & Energy, and Man...
# 564  Computer Hardware, Computer Software, and Info...
# 565                         Research and Biotechnology
#
#     Avg_Salary Min_Salary_Num Max_Salary_Num Avg_Salary_Num
# 0
# 1
# 2
# 3
# 4
# ..         ...            ...            ...            ...
# 561
# 562
# 563
# 564
# 565
#
# [566 rows x 15 columns]

# %%
# for the reddit post
# use this for markdown tables https://www.tablesgenerator.com/markdown_tables
jobs_df1['Salary_num'] = pd.to_numeric(jobs_df1['Salary'].str.replace('\$|,|k','')) # make it a number for sorting
jobs_df1 = jobs_df1.sort_values(by='Salary_num',ascending=False)
filter_sal = jobs_df1['Salary'].notnull()
filter_analyst = jobs_df1['Job Title'].str.contains('analyst',case=False)
# make the column order a bit nicer
col_order = ['Salary', 'Job Title',
 'Company',
 'Job Location',
 'Job URL'
 ]
jobs_sal_df = jobs_df1[filter_sal & filter_analyst][col_order]
jobs_sal_df.to_csv('test.csv',index=False)

# %%
jobs_df1 = jobs_df1.sort_values(by='Min_Salary_Num',ascending=False)
filter_sal = jobs_df1['Min_Salary_Num'].notnull()
# make the column order a bit nicer
col_order = ['Min_Salary','Max_Salary','Avg_Salary','Job Title','Company','Job Location',]
jobs_sal_df = jobs_df1[filter_sal][col_order]
jobs_sal_df
# Out:
#     Min_Salary Max_Salary Avg_Salary  \
# 180   $250,000   $250,000   $250,000
# 394   $175,000   $175,000   $175,000
# 292   $130,000   $130,000   $130,000
# 500   $120,000   $120,000   $120,000
# 510   $120,000   $140,000   $130,000
# 53    $119,442   $119,442   $119,442
# 260   $111,077   $111,077   $111,077
# 456   $111,077   $111,077   $111,077
# 233   $100,000   $100,000   $100,000
# 242   $100,000   $140,000   $120,000
# 475    $60,000    $80,000    $70,000
#
#                                              Job Title  \
# 180            Development Manager/Solutions Architect
# 394          Solution Architect - Digital & Mobile App
# 292         Solution Architect - Data & Cloud Delivery
# 500  Lead Platform Engineer - Enterprise Hcm | Peop...
# 510  Lead Platform Engineer - Enterprise Hcm | Peop...
# 53                                  Solution architect
# 260          Senior Software Engineer - Multiple Roles
# 456          Senior Software Engineer - Multiple Roles
# 233  Senior Solution Consultant - Hybrid Presales a...
# 242                   Data Engineer / Sr. Data Analyst
# 475              Software Engineer - Digital Solutions
#
#                                 Company  \
# 180                     FIRESOFT People
# 394                        Jobx Pty Ltd
# 292           Command Recruitment Group
# 500        Randstad Education Australia
# 510        Randstad Education Australia
# 53                   City of Boroondara
# 260  NSW Department of Customer Service
# 456                      I work for NSW
# 233                      DXC Technology
# 242                             Troocoo
# 475                   Jobs on jobactive
#
#                                    Job Location
# 180          Sydney, New South Wales, Australia
# 394          Sydney, New South Wales, Australia
# 292          Sydney, New South Wales, Australia
# 500             Brisbane, Queensland, Australia
# 510             Brisbane, Queensland, Australia
# 53              Camberwell, Victoria, Australia
# 260          Sydney, New South Wales, Australia
# 456          Sydney, New South Wales, Australia
# 233  Macquarie Park, New South Wales, Australia
# 242              Melbourne, Victoria, Australia
# 475              Melbourne, Victoria, Australia

# %% [markdown]
# ## Finding which tech stack is most in demand

# %%
# Import stopwords with nltk.
from nltk.corpus import stopwords
import nltk

# %%
# nltk doesn't come with everything
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jason.chiu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# stop is a list of stopwords
stop = stopwords.words('english')
newStopWords = []
stop.extend(newStopWords)

# %%
# multi word tech stack
multi_tech = {
    'power bi':'power_bi',
    'powerbi':'power_bi',
    'nosql':'no_sql',
    'no sql':'no_sql',
    'data studio':'data_studio',
    'datastudio':'data_studio',
    ' r ':' _r_ ',
    'datarobot':'data_robot',
    'data robot':'data_robot',
    'google cloud platform':'gcp'
}
darlo_multi ={
    'adobe xd':'adobe_xd',
    'web design':'web_design',
    'webdesign':'web_design',
    'mobile app':'mobile_app',
    'mobile application':'mobile_app',
    'product design':'product_design',
    'user interface':'user_interface',
    'adobe creative cloud':'adobe_creative_cloud',
    'adobe suite':'adobe_creative_cloud',
    'optimal sort':'optimal_sort',
    'photoshop':'adobe_photoshop',
    'illustrator':'adobe_illustrator',
    'after effect':'adobe_after_effects'
}

# %%
jobs_df = pd.read_csv('ux designer_Australia_2021-59-31.csv')
jobs_df.head()
# Out:
#    Unnamed: 0                                Job Title               Company  \
# 0           0                      Lead UX/UI Designer        Robert Walters
# 1           1                 UX Designer / Researcher       Endeavour Group
# 2           2                              UX Designer       Endeavour Group
# 3           3                       Senior UX Designer            Peoplebank
# 4           4  Senior UX Researcher / Service Designer  Objective Experience
#
#                           Job Location  \
# 0  Perth, Western Australia, Australia
# 1   Sydney, New South Wales, Australia
# 2   Sydney, New South Wales, Australia
# 3   Sydney, New South Wales, Australia
# 4   Sydney, New South Wales, Australia
#
#                                           Job URL  \
# 0  https://www.linkedin.com/jobs/view/2645697068/
# 1  https://www.linkedin.com/jobs/view/2496656500/
# 2  https://www.linkedin.com/jobs/view/2642705335/
# 3  https://www.linkedin.com/jobs/view/2619882773/
# 4  https://www.linkedin.com/jobs/view/2661207413/
#
#                                      Job Description   Seniority Level  \
# 0   This opportunity is within a leading geoscien...  Mid-Senior level
# 1   About UsEndeavour Group was created in 2020 t...  Mid-Senior level
# 2   About UsEndeavour Group was created in 2020 t...  Mid-Senior level
# 3   Location: Sydney, New South Wales Job Type: P...         Associate
# 4   We are looking for a brilliant researcher / s...               NaN
#
#   Employment Type                                      Job Function  \
# 0       Full-time                            Information Technology
# 1       Full-time  Design, Art/Creative, and Information Technology
# 2       Full-time  Design, Art/Creative, and Information Technology
# 3        Contract  Design, Art/Creative, and Information Technology
# 4       Full-time                                               NaN
#
#                                           Industries Min_Salary Max_Salary  \
# 0                                    Mining & Metals        NaN        NaN
# 1  Computer Software, Retail, and Financial Services        NaN        NaN
# 2  Computer Software, Retail, and Financial Services        NaN        NaN
# 3  Information Technology and Services, Computer ...        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Avg_Salary  Min_Salary_Num  Max_Salary_Num  Avg_Salary_Num
# 0        NaN             NaN             NaN             NaN
# 1        NaN             NaN             NaN             NaN
# 2        NaN             NaN             NaN             NaN
# 3        NaN             NaN             NaN             NaN
# 4        NaN             NaN             NaN             NaN

# %%
words = jobs_df['Job Description'].to_frame()
words.columns = ['words']
# below regex removes any non-word, non-space characters. This will mess up some words, but we're only interested in tech we know about, so it doesn't matter much
words['words'] = words['words'].str.replace("[^\w\s]", "").str.lower()
words['words'] = words['words'].apply(lambda x: ' '.join([item for item in x.split() if item not in stop]))
for key in multi_tech:
    words['words'] = words['words'].str.replace(key,multi_tech[key])
# for key in darlo_multi:
#     words['words'] = words['words'].str.replace(key,darlo_multi[key])

freq = pd.DataFrame(words['words'].str.split(expand=True).stack().value_counts()).reset_index()
freq.columns = ['words','count']
freq.head(30)
# Out:
#            words  count
# 0     experience   2888
# 1      technical   2273
# 2      solutions   2068
# 3       business   1883
# 4           work   1778
# 5           team   1593
# 6       solution   1495
# 7       customer   1477
# 8      customers   1459
# 9         skills   1259
# 10         cloud   1134
# 11    technology   1125
# 12          role   1022
# 13         sales   1016
# 14   development   1001
# 15          data    992
# 16      services    983
# 17        design    965
# 18       working    948
# 19       support    948
# 20      security    912
# 21     knowledge    906
# 22       ability    863
# 23    management    802
# 24        people    800
# 25  architecture    757
# 26     including    734
# 27     microsoft    729
# 28       product    683
# 29  requirements    671

# %%
# for love Adobe suite, Lookback, Axure, Sketch, InVision, Omnigraffle, Userzoom, Optimal sort, Figma
# to get phrases, replace powerbi and power bi with power_bi
tech1 = ['figma','sketch','invision','lookback',
        'askable','miro','confluence','jira','axure',
        'omnigraffle','userzoom','html','css','javascript']
tech2 = tech1 + (list(set(darlo_multi.values())))
tech = '|'.join(tech2)
# these words contain things like aws and excel
exclude1 = ['capital','laws','excellen']
exclude = '|'.join(exclude1)

filter3 = freq['words'].str.contains(tech)
filter4 = freq['words'].str.contains(exclude)

# freq[(filter3) & ~(filter4)].head(10)
# freq[filter5]

top10_tech_df = freq[(filter3) & ~(filter4)].head(10)
# make the names nicer
top10_tech_df['words'] = top10_tech_df['words'].str.replace('_',' ').str.strip().str.upper()
top10_tech_df
# Out:
#                  words  count
# 135     PRODUCT DESIGN    104
# 143   PRODUCT DESIGNER    100
# 146              FIGMA     97
# 186             SKETCH     81
# 317           INVISION     51
# 412  PRODUCT DESIGNERS     41
# 418     USER INTERFACE     40
# 714                CSS     23
# 730               JIRA     23
# 773               HTML     22

# %%
# freq is a word (single word) count
# to get phrases, replace powerbi and power bi with power_bi
tech1 = ['sql','python','excel',
        'tableau','aws','gcp',
        'azure','qlik','matlab','hadoop',
        'looker','domo','dbt', 'kafka','spark'
        'datorama','_r_']
tech2 = tech1 + (list(set(multi_tech.values())))
tech = '|'.join(tech2)
# these words contain things like aws and excel
exclude1 = ['capital','laws','excellen']
exclude = '|'.join(exclude1)

filter3 = freq['words'].str.contains(tech)
filter4 = freq['words'].str.contains(exclude)

# freq[(filter3) & ~(filter4)].head(10)
# freq[filter5]

top10_tech_df = freq[(filter3) & ~(filter4)].head(10)
# make the names nicer
top10_tech_df['words'] = top10_tech_df['words'].str.replace('_',' ').str.strip().str.upper()
top10_tech_df
# Out:
#          words  count
# 49       AZURE    539
# 88         AWS    348
# 429        SQL    102
# 538     PYTHON     85
# 920    TABLEAU     46
# 1394       GCP     27
# 1571     EXCEL     23
# 1631    HADOOP     22
# 1720    NO SQL     20
# 1910  POWER BI     17

# %% [markdown]
# # Writing the data to our database

# %%
# looks like we need none of the above, the auth is contained inside pygsheets
# need to enable google sheets api and google drive api 
# then share your spreadsheet with the client_email in your key.json file
import pygsheets
client = pygsheets.authorize(service_file='jason2021-key.json')

# %%
# trying one from jason@wvc, also one from jasonsan to share
# so it doesn't matter who the owner of the google sheet is, only that we share it with the client_email
client.spreadsheet_titles()
# Out:
# ['Pvolo - Bag1', 'Data Analyst Course planning', 'Linkedin Learning Project']

# %%
# open spreadsheet name
spreadsheet1 = client.open("Linkedin Learning Project")

# %%
# check the names of the tabs or worksheets
spreadsheet1.worksheets()
# Out:
# [<Worksheet 'Raw Data' index:0>,
#  <Worksheet 'Top 10 Skills' index:1>,
#  <Worksheet 'Salaries' index:2>]

# %%
# open the worksheet or tab
worksheet1 = spreadsheet1.worksheet_by_title('Raw Data')

# %%
# Put sheet into a dataframe
df = worksheet1.get_as_df()
df.head()
# Out:
#                                       Job Title                    Company  \
# 0           Data Analyst, Research and Insights                     Google
# 1  Tableau Business Intelligence Senior Analyst                 Salesforce
# 2                 Data Analyst, Churn Analytics  Disney Streaming Services
# 3                       Product Data Analyst II                       Uber
# 4                 Senior Data Analyst - Content                       Hulu
#
#         Job Location                                            Job URL  \
# 0       New York, NY  https://www.linkedin.com/jobs/view/2616405818/...
# 1  San Francisco, CA  https://www.linkedin.com/jobs/view/2615511362/...
# 2       New York, NY  https://www.linkedin.com/jobs/view/2620559153/...
# 3       New York, NY  https://www.linkedin.com/jobs/view/2632664783/...
# 4   Santa Monica, CA  https://www.linkedin.com/jobs/view/2620557390/...
#
#                                      Job Description   Seniority Level  \
# 0   Note: By applying to this position you will h...    Not Applicable
# 1   To get the best candidate experience, please ...    Not Applicable
# 2   Job Summary: We are looking for an experience...  Mid-Senior level
# 3   About The RoleAre you interested in driving b...    Not Applicable
# 4   SummaryThe Disney Median & Entertainment Dist...  Mid-Senior level
#
#   Employment Type                                       Job Function  \
# 0       Full-time                             Information Technology
# 1       Full-time      Research, Analyst, and Information Technology
# 2       Full-time  Quality Assurance, Information Technology, and...
# 3       Full-time                             Information Technology
# 4       Full-time     Business Development, Analyst, and Engineering
#
#                                           Industries Min_Salary Max_Salary  \
# 0                  Information Services and Internet
# 1  Computer Software, Information Technology and ...
# 2  Marketing and Advertising, Computer Software, ...
# 3  Computer Software, Consumer Services, and Info...
# 4  Marketing and Advertising, Computer Software, ...
#
#   Avg_Salary Min_Salary_Num Max_Salary_Num Avg_Salary_Num           City State
# 0                                                               New York    NY
# 1                                                          San Francisco    CA
# 2                                                               New York    NY
# 3                                                               New York    NY
# 4                                                           Santa Monica    CA

# %%
# in the tab write our dataframe with a starting coordinates row,col
worksheet1.set_dataframe(jobs_df_withsal,start=(1,1))

# %%
# next the worksheet or tab
worksheet2 = spreadsheet1.worksheet_by_title('Top 10 Skills')
worksheet2.set_dataframe(top10_tech_df,start=(1,1))

# %%
# next the worksheet or tab
worksheet3 = spreadsheet1.worksheet_by_title('Salaries')
worksheet3.set_dataframe(jobs_sal_df,start=(1,1))
